# %% [markdown]
# ## 1.Degreed Users Group Creation App

# %%
import pandas as pd
from datetime import date
import os
import subprocess

# %%
data = pd.read_excel (r'C:\Users\guibo\OneDrive\Área de Trabalho\Degreed\User_file template_TIC.xlsx', sheet_name='User List')
rules = pd.read_excel (r'C:\Users\guibo\OneDrive\Área de Trabalho\Degreed\BusinessRules Template_TIC.xlsx', sheet_name='Business Rules')

# %% [markdown]
# ## 2.Visualising User Data

# %%
data
# Out:
#     UniqueID             FullName  FirstName   LastName  \
# 0     173657            Kim Blank        Kim      Blank
# 1     173658        Jeff Shilling       Jeff   Shilling
# 2     173659         Nancy Barnes      Nancy     Barnes
# 3     173660         Hank Edwards       Hank    Edwards
# 4     173661             Amy Cuth        Amy       Cuth
# 5     173662        Jaylan Walter     Jaylan     Walter
# 6     172663         Nora Harrell       Nora    Harrell
# 7     173664        Carlos McCann     Carlos     McCann
# 8     173665       Kailee Johnson     Kailee    Johnson
# 9     173666     Mathias Villegas    Mathias   Villegas
# 10    173667          Mylie Carey      Mylie      Carey
# 11    173668          Diego Duffy      Diego      Duffy
# 12    173669        Fatime Guerra     Fatima     Guerra
# 13    173770        Joseph Osborn     Joseph     Osborn
# 14    173771         Nora Sanchez       Nora    Sanchez
# 15    173772          Derek Eaton     Derek       Eaton
# 16    173773       Karlie Hartman     Karlie    Hartman
# 17    173774        Killian Bryan    Killian      Bryan
# 18    173775      Guillermo Josph  Guillermo     Joseph
# 19    173776           Hafiz Luna      Hafiz       Luna
# 20    173777         Kate Huffman       Kate    Huffman
# 21    173778        Danielle West   Danielle       West
# 22    173779            Alex Pace       Alex       Pace
# 23    173780           Jamie Carr      Jamie       Carr
# 24    173781       Natalya Lucero    Natalya     Lucero
# 25    173782  Guilherme Bortolaso  Guilherme  Bortolaso
#
#                         Email  ManagerUniqueID Delete  \
# 0          kim.blank@Acme.com            11034      N
# 1      jeff.shilling@acme.com            11587      N
# 2       nancy.barnes@acme.com            10426      N
# 3       hank.edwards@acme.com            10033      N
# 4           amy.cuth@acme.com            14422      N
# 5      jaylan.walter@acme.com            12256      N
# 6       nora.harrell@acme.com            54956      N
# 7      carlos.mccann@acme.com            98122      N
# 8     kailee.johnson@acme.com            98118      N
# 9   mathias.villegas@acme.com            11053      N
# 10       mylie.carey@acme.com            11674      N
# 11       diego.duffy@acme.com            11987      N
# 12     fatima.guerra@acme.com            11524      N
# 13     joseph.osborn@acme.com            11999      N
# 14      nora.sanchez@acme.com            11888      N
# 15       derek.eaton@acme.com            11678      N
# 16    karlie.hartman@acme.com            11900      N
# 17     killian.bryan@acme.com            11244      N
# 18  guillermo.joseph@acme.com            11322      N
# 19        hafiz.luna@acme.com            11544      N
# 20      kate.huffman@acme.com            16577      N
# 21     danielle.west@acme.com            18395      N
# 22         alex.pace@acme.com            19835      N
# 23        jamie.carr@acme.com            12245      N
# 24    natalya.lucero@acme.com            14556      N
# 25     gui.bortolaso@acme.com            14557      Y
#
#                   Department  Hire Date          Office Location  \
# 0                Procurement 2004-12-01           Beijing, China
# 1              Lead Sourcing 2010-01-08               London, UK
# 2               Supply Chain 2019-06-01             Tokyo, Japan
# 3         Talent Acquisition 2003-03-05        Sao Paulo, Brazil
# 4                    Digital 2018-05-05      Mexico City, Mexico
# 5                      FP &A 2019-06-01             New York, NY
# 6                      Field 2016-02-01          Toronto, Canada
# 7     Learning & Development 2018-10-02         Bangalore, India
# 8               Supply Chain 2003-12-01          Los Angeles, CA
# 9                    Digital 2003-12-01              Chicago, IL
# 10               Procurement 2018-07-01  Buenos Aires, Argentina
# 11                     Field 2018-10-01      Mexico City, Mexico
# 12                        QA 2015-04-02        Sao Paulo, Brazil
# 13        Talent Acquisition 2004-12-01             New York, NY
# 14  Partnerships & Alliances 2010-01-08             New York, NY
# 15                Accounting 2019-06-01           Beijing, China
# 16                     Field 2003-03-05           Beijing, China
# 17                        QA 2018-05-05             Tokyo, Japan
# 18    Learning & Development 2019-06-01          Toronto, Canada
# 19                   Digital 2016-02-01               London, UK
# 20                Accounting 2018-10-02  Buenos Aires, Argentina
# 21                     Field 2003-12-01          Los Angeles, CA
# 22              Supply Chain 2003-12-01          Los Angeles, CA
# 23        Talent Acquisition 2018-07-01          Toronto, Canada
# 24                   Digital 2018-10-01             New York, NY
# 25                   Digital 2018-10-01             New York, NY
#
#    Business Unit People Manager
# 0        Finance              Y
# 1          Sales              Y
# 2     Production              N
# 3             HR              N
# 4      Marketing              Y
# 5        Finance              N
# 6          Sales              Y
# 7             HR              Y
# 8     Production              N
# 9      Marketing              N
# 10       Finance              N
# 11         Sales              N
# 12    Production              Y
# 13            HR              Y
# 14     Marketing              Y
# 15       Finance              N
# 16         Sales              Y
# 17    Production              N
# 18            HR              Y
# 19     Marketing              Y
# 20       Finance              Y
# 21         Sales              N
# 22    Production              N
# 23            HR              Y
# 24     Marketing              Y
# 25     Marketing              Y

# %% [markdown]
# ### 2.1 Updating User Date Before Proceed

# %%
for i in range(len(data)):
    if data["Delete"][i] == "Y":
        data = data.drop([i])
data
# Out:
#     UniqueID          FullName  FirstName  LastName  \
# 0     173657         Kim Blank        Kim     Blank
# 1     173658     Jeff Shilling       Jeff  Shilling
# 2     173659      Nancy Barnes      Nancy    Barnes
# 3     173660      Hank Edwards       Hank   Edwards
# 4     173661          Amy Cuth        Amy      Cuth
# 5     173662     Jaylan Walter     Jaylan    Walter
# 6     172663      Nora Harrell       Nora   Harrell
# 7     173664     Carlos McCann     Carlos    McCann
# 8     173665    Kailee Johnson     Kailee   Johnson
# 9     173666  Mathias Villegas    Mathias  Villegas
# 10    173667       Mylie Carey      Mylie     Carey
# 11    173668       Diego Duffy      Diego     Duffy
# 12    173669     Fatime Guerra     Fatima    Guerra
# 13    173770     Joseph Osborn     Joseph    Osborn
# 14    173771      Nora Sanchez       Nora   Sanchez
# 15    173772       Derek Eaton     Derek      Eaton
# 16    173773    Karlie Hartman     Karlie   Hartman
# 17    173774     Killian Bryan    Killian     Bryan
# 18    173775   Guillermo Josph  Guillermo    Joseph
# 19    173776        Hafiz Luna      Hafiz      Luna
# 20    173777      Kate Huffman       Kate   Huffman
# 21    173778     Danielle West   Danielle      West
# 22    173779         Alex Pace       Alex      Pace
# 23    173780        Jamie Carr      Jamie      Carr
# 24    173781    Natalya Lucero    Natalya    Lucero
#
#                         Email  ManagerUniqueID Delete  \
# 0          kim.blank@Acme.com            11034      N
# 1      jeff.shilling@acme.com            11587      N
# 2       nancy.barnes@acme.com            10426      N
# 3       hank.edwards@acme.com            10033      N
# 4           amy.cuth@acme.com            14422      N
# 5      jaylan.walter@acme.com            12256      N
# 6       nora.harrell@acme.com            54956      N
# 7      carlos.mccann@acme.com            98122      N
# 8     kailee.johnson@acme.com            98118      N
# 9   mathias.villegas@acme.com            11053      N
# 10       mylie.carey@acme.com            11674      N
# 11       diego.duffy@acme.com            11987      N
# 12     fatima.guerra@acme.com            11524      N
# 13     joseph.osborn@acme.com            11999      N
# 14      nora.sanchez@acme.com            11888      N
# 15       derek.eaton@acme.com            11678      N
# 16    karlie.hartman@acme.com            11900      N
# 17     killian.bryan@acme.com            11244      N
# 18  guillermo.joseph@acme.com            11322      N
# 19        hafiz.luna@acme.com            11544      N
# 20      kate.huffman@acme.com            16577      N
# 21     danielle.west@acme.com            18395      N
# 22         alex.pace@acme.com            19835      N
# 23        jamie.carr@acme.com            12245      N
# 24    natalya.lucero@acme.com            14556      N
#
#                   Department  Hire Date          Office Location  \
# 0                Procurement 2004-12-01           Beijing, China
# 1              Lead Sourcing 2010-01-08               London, UK
# 2               Supply Chain 2019-06-01             Tokyo, Japan
# 3         Talent Acquisition 2003-03-05        Sao Paulo, Brazil
# 4                    Digital 2018-05-05      Mexico City, Mexico
# 5                      FP &A 2019-06-01             New York, NY
# 6                      Field 2016-02-01          Toronto, Canada
# 7     Learning & Development 2018-10-02         Bangalore, India
# 8               Supply Chain 2003-12-01          Los Angeles, CA
# 9                    Digital 2003-12-01              Chicago, IL
# 10               Procurement 2018-07-01  Buenos Aires, Argentina
# 11                     Field 2018-10-01      Mexico City, Mexico
# 12                        QA 2015-04-02        Sao Paulo, Brazil
# 13        Talent Acquisition 2004-12-01             New York, NY
# 14  Partnerships & Alliances 2010-01-08             New York, NY
# 15                Accounting 2019-06-01           Beijing, China
# 16                     Field 2003-03-05           Beijing, China
# 17                        QA 2018-05-05             Tokyo, Japan
# 18    Learning & Development 2019-06-01          Toronto, Canada
# 19                   Digital 2016-02-01               London, UK
# 20                Accounting 2018-10-02  Buenos Aires, Argentina
# 21                     Field 2003-12-01          Los Angeles, CA
# 22              Supply Chain 2003-12-01          Los Angeles, CA
# 23        Talent Acquisition 2018-07-01          Toronto, Canada
# 24                   Digital 2018-10-01             New York, NY
#
#    Business Unit People Manager
# 0        Finance              Y
# 1          Sales              Y
# 2     Production              N
# 3             HR              N
# 4      Marketing              Y
# 5        Finance              N
# 6          Sales              Y
# 7             HR              Y
# 8     Production              N
# 9      Marketing              N
# 10       Finance              N
# 11         Sales              N
# 12    Production              Y
# 13            HR              Y
# 14     Marketing              Y
# 15       Finance              N
# 16         Sales              Y
# 17    Production              N
# 18            HR              Y
# 19     Marketing              Y
# 20       Finance              Y
# 21         Sales              N
# 22    Production              N
# 23            HR              Y
# 24     Marketing              Y

# %% [markdown]
# ## 3.Visualising Rules

# %%
rules
# Out:
#    Last Updated               if op 1                  equals 1  and if 2  \
# 0    2020-05-12         UniqueID   >=                         0       NaN
# 1    2020-05-12    Business Unit    =                   Finance       NaN
# 2    2020-05-12    Business Unit    =                     Sales       NaN
# 3    2020-05-12    Business Unit    =                Production       NaN
# 4    2020-05-12    Business Unit    =                        HR       NaN
# 5    2020-05-12    Business Unit    =                 Marketing       NaN
# 6    2020-05-12   People Manager    =                         Y       NaN
# 7    2020-05-12  Office Location    =            Beijing, China       NaN
# 8    2020-05-13  Office Location    =                London, UK       NaN
# 9    2020-05-14  Office Location    =              Tokyo, Japan       NaN
# 10   2020-05-15  Office Location    =         Sao Paulo, Brazil       NaN
# 11   2020-05-16  Office Location    =       Mexico City, Mexico       NaN
# 12   2020-05-17  Office Location    =              New York, NY       NaN
# 13   2020-05-18  Office Location    =           Toronto, Canada       NaN
# 14   2020-05-19  Office Location    =          Bangalore, India       NaN
# 15   2020-05-20  Office Location    =           Los Angeles, CA       NaN
# 16   2020-05-21  Office Location    =               Chicago, IL       NaN
# 17   2020-05-22  Office Location    =   Buenos Aires, Argentina       NaN
#
#     op 2  equals 2          Groups Delete
# 0    NaN       NaN       All Hands      N
# 1    NaN       NaN         Finance      N
# 2    NaN       NaN           Sales      N
# 3    NaN       NaN      Production      N
# 4    NaN       NaN              HR      N
# 5    NaN       NaN       Marketing      N
# 6    NaN       NaN  Leadership Dev      N
# 7    NaN       NaN            APAC      N
# 8    NaN       NaN            EMEA      N
# 9    NaN       NaN            APAC      N
# 10   NaN       NaN           LATAM      N
# 11   NaN       NaN           NAMER      N
# 12   NaN       NaN           NAMER      N
# 13   NaN       NaN           NAMER      N
# 14   NaN       NaN            APAC      N
# 15   NaN       NaN           NAMER      N
# 16   NaN       NaN           NAMER      N
# 17   NaN       NaN           LATAM      N

# %% [markdown]
# ### 3.1 Updating Rules Before Proceed

# %%
for i in range(len(rules)):
    if rules["Delete"][i] == "Y":
        rules = rules.drop([i])
rules
# Out:
#    Last Updated               if op 1                  equals 1  and if 2  \
# 0    2020-05-12         UniqueID   >=                         0       NaN
# 1    2020-05-12    Business Unit    =                   Finance       NaN
# 2    2020-05-12    Business Unit    =                     Sales       NaN
# 3    2020-05-12    Business Unit    =                Production       NaN
# 4    2020-05-12    Business Unit    =                        HR       NaN
# 5    2020-05-12    Business Unit    =                 Marketing       NaN
# 6    2020-05-12   People Manager    =                         Y       NaN
# 7    2020-05-12  Office Location    =            Beijing, China       NaN
# 8    2020-05-13  Office Location    =                London, UK       NaN
# 9    2020-05-14  Office Location    =              Tokyo, Japan       NaN
# 10   2020-05-15  Office Location    =         Sao Paulo, Brazil       NaN
# 11   2020-05-16  Office Location    =       Mexico City, Mexico       NaN
# 12   2020-05-17  Office Location    =              New York, NY       NaN
# 13   2020-05-18  Office Location    =           Toronto, Canada       NaN
# 14   2020-05-19  Office Location    =          Bangalore, India       NaN
# 15   2020-05-20  Office Location    =           Los Angeles, CA       NaN
# 16   2020-05-21  Office Location    =               Chicago, IL       NaN
# 17   2020-05-22  Office Location    =   Buenos Aires, Argentina       NaN
#
#     op 2  equals 2          Groups Delete
# 0    NaN       NaN       All Hands      N
# 1    NaN       NaN         Finance      N
# 2    NaN       NaN           Sales      N
# 3    NaN       NaN      Production      N
# 4    NaN       NaN              HR      N
# 5    NaN       NaN       Marketing      N
# 6    NaN       NaN  Leadership Dev      N
# 7    NaN       NaN            APAC      N
# 8    NaN       NaN            EMEA      N
# 9    NaN       NaN            APAC      N
# 10   NaN       NaN           LATAM      N
# 11   NaN       NaN           NAMER      N
# 12   NaN       NaN           NAMER      N
# 13   NaN       NaN           NAMER      N
# 14   NaN       NaN            APAC      N
# 15   NaN       NaN           NAMER      N
# 16   NaN       NaN           NAMER      N
# 17   NaN       NaN           LATAM      N

# %% [markdown]
# ## 4.Getting unique Business Units Groups

# %%
bu_unique = data["Business Unit"].unique()

# %%
bu_unique
# Out:
# array(['Finance', 'Sales', 'Production', 'HR', 'Marketing'], dtype=object)

# %% [markdown]
# ## 5.Getting unique Region Groups

# %%
locations_unique = data["Office Location"].unique()

# %%
locations_unique = list(locations_unique)

# %%
locations_unique
# Out:
# ['Beijing, China',
#  'London, UK',
#  'Tokyo, Japan',
#  'Sao Paulo, Brazil',
#  'Mexico City, Mexico',
#  'New York, NY',
#  'Toronto, Canada',
#  'Bangalore, India',
#  'Los Angeles, CA',
#  'Chicago, IL',
#  'Buenos Aires, Argentina']

# %%
regions = {'Sao Paulo, Brazil': 'LATAM',
           'Mexico City, Mexico': 'NAMER',
           'New York, NY': 'NAMER',
           'Toronto, Canada': 'NAMER',
           'Bangalore, India': 'APAC',
           'Los Angeles, CA': 'NAMER',
           'Chicago, IL': 'NAMER',
           'Buenos Aires, Argentina': 'LATAM',
           'Beijing, China': 'APAC',
           'Tokyo, Japan': 'APAC',
           'London, UK': 'EMEA'}

# %% [markdown]
# ### 5.1 Function to get Region

# %%
def get_region(location):
    for key,value in regions.items():
        if key == location:
            return value

# %%
get_region('Toronto, Canada')
# Out:
# 'NAMER'

# %% [markdown]
# ## 6.Construction of User Groups file format

# %% [markdown]
# ### 6.1 Inserting Basic Data

# %%
users_file = list(data.head())

# %% [markdown]
# ### 6.2 Inserting "All Hands" Group

# %%
users_file.append("All Hands")

# %% [markdown]
# ### 6.3 Insert Business Units Groups

# %%
for bu in bu_unique:
    users_file.append(bu)

# %% [markdown]
# ### 6.4 Insert  Leadership Development Group

# %%
users_file.append("Leadership Dev")

# %% [markdown]
# ### 6.5 Insert Region Groups

# %%
users_file.append("APAC")
users_file.append("EMEA")
users_file.append("LATAM")
users_file.append("NAMER")

# %% [markdown]
# ## 7.Rules parser from Excel Business Rules Sheet - Sample Data

# %%
sample = data.iloc[10]
sample
# Out:
# UniqueID                            173667
# FullName                       Mylie Carey
# FirstName                            Mylie
# LastName                             Carey
# Email                 mylie.carey@acme.com
# ManagerUniqueID                      11674
# Delete                                   N
# Department                     Procurement
# Hire Date              2018-07-01 00:00:00
# Office Location    Buenos Aires, Argentina
# Business Unit                      Finance
# People Manager                           N
# Name: 10, dtype: object

# %%
assertion1 = []
assertion2 = []

# %%
def assert_rules_1(data):
    for if_s, opt_1, equals_1 in zip(rules['if'],rules['op 1'],rules['equals 1']): ## Assertion coverting from Excel
        if opt_1 == "=":
            if data[if_s] == equals_1:
                assertion1.append(True)
            else:
                assertion1.append(False)
        elif opt_1 == ">":
            if data[if_s] > equals_1:
                assertion1.append(True)
            else:
                assertion1.append(False)
        elif opt_1 == "<":
            if data[if_s] < equals_1:
                assertion1.append(True)
            else:
                assertion1.append(False)
        elif opt_1 == "<=":
            if data[if_s] <= equals_1:
                assertion1.append(True)
            else:
                assertion1.append(False)
        elif opt_1 == ">=":
            if data[if_s] >= equals_1:
                assertion1.append(True)
            else:
                assertion1.append(False)
                
def assert_rules_2(data):
    for if_s, opt_2, equals_2 in zip(rules['and if 2'],rules['op 2'],rules['equals 2']): ## Assertion coverting from Excel
        if opt_2 == "=":
            if data[if_s] == equals_2:
                assertion2.append(True)
            else:
                assertion2.append(False)
        elif opt_2 == ">":
            if data[if_s] > equals_2:
                assertion2.append(True)
            else:
                assertion2.append(False)
        elif opt_2 == "<":
            if data[if_s] < equals_2:
                assertion2.append(True)
            else:
                assertion2.append(False)
        elif opt_2 == "<=":
            if data[if_s] <= equals_2:
                assertion2.append(True)
            else:
                assertion2.append(False)
        elif opt_2 == ">=":
            if data[if_s] >= equals_2:
                assertion2.append(True)
            else:
                assertion2.append(False)
        else:
            assertion2.append(True)

# %%
assert_rules_1(sample)
assert_rules_2(sample)

# %% [markdown]
# ### 7.1 Assigment Groups Matrix - Business Rules Results

# %%
group_matrix = []
for assert_1,assert_2 in zip(assertion1,assertion2):
    if assert_1 and assert_2:
        group_matrix.append("Y")
    else:
        group_matrix.append("N")

# %% [markdown]
# ## 8. Dataframe strucuture population Integrity Test

# %%
file = pd.DataFrame(columns = users_file)

# %%
temp_data=[]
for temp in sample:
    temp_data.append(temp)

# %%
for i,rule in zip(range(len(rules)),rules["Groups"]):
    if rule == "All Hands":
        temp_data.append(group_matrix[i])
for i,rule in zip(range(len(rules)),rules["Groups"]):
    if rule == "Finance":
        temp_data.append(group_matrix[i])
for i,rule in zip(range(len(rules)),rules["Groups"]):
    if rule == "Sales":
        temp_data.append(group_matrix[i])
for i,rule in zip(range(len(rules)),rules["Groups"]):
    if rule == "Production":
        temp_data.append(group_matrix[i])
for i,rule in zip(range(len(rules)),rules["Groups"]):
    if rule == "HR":
        temp_data.append(group_matrix[i])
for i,rule in zip(range(len(rules)),rules["Groups"]):
    if rule == "Marketing":
        temp_data.append(group_matrix[i])
for i,rule in zip(range(len(rules)),rules["Groups"]):
    if rule == "Leadership Dev":
        temp_data.append(group_matrix[i])

# %%
if get_region(sample["Office Location"]) == "LATAM":
    temp_data.extend(("N","N","Y","N"))
elif get_region(sample["Office Location"]) == "NAMER":
    temp_data.extend(("N","N","N","Y"))
elif get_region(sample["Office Location"]) == "APAC":
    temp_data.extend(("Y","N","N","N"))
elif get_region(sample["Office Location"]) == "EMEA":
    temp_data.extend(("N","Y","N","N"))

# %%
file.loc[len(file)] = temp_data

# %%
file
# Out:
#   UniqueID     FullName FirstName LastName                 Email  \
# 0   173667  Mylie Carey     Mylie    Carey  mylie.carey@acme.com
#
#   ManagerUniqueID Delete   Department  Hire Date          Office Location  \
# 0           11674      N  Procurement 2018-07-01  Buenos Aires, Argentina
#
#    ... Finance Sales Production HR Marketing Leadership Dev APAC EMEA LATAM  \
# 0  ...       Y     N          N  N         N              N    N    N     Y
#
#   NAMER
# 0     N
#
# [1 rows x 23 columns]

# %% [markdown]
# ## 9. Populating Dataframe to CSV file

# %%
csv = pd.DataFrame(columns = users_file)

# %%
for i in range(len(data)):
    assertion1 = []
    assertion2 = []
    assert_rules_1(data.iloc[i])
    assert_rules_2(data.iloc[i])

    
    group_matrix = []
    for assert_1,assert_2 in zip(assertion1,assertion2):
        if assert_1 and assert_2:
            group_matrix.append("Y")
        else:
            group_matrix.append("N")
            
    temp_data=[]
    for temp in data.iloc[i]:
        temp_data.append(temp)
        
        
    for j,rule in zip(range(len(rules)),rules["Groups"]):
        if rule == "All Hands":
            temp_data.append(group_matrix[j])
    for j,rule in zip(range(len(rules)),rules["Groups"]):
        if rule == "Finance":
            temp_data.append(group_matrix[j])
    for j,rule in zip(range(len(rules)),rules["Groups"]):
        if rule == "Sales":
            temp_data.append(group_matrix[j])
    for j,rule in zip(range(len(rules)),rules["Groups"]):
        if rule == "Production":
            temp_data.append(group_matrix[j])
    for j,rule in zip(range(len(rules)),rules["Groups"]):
        if rule == "HR":
            temp_data.append(group_matrix[j])
    for j,rule in zip(range(len(rules)),rules["Groups"]):
        if rule == "Marketing":
            temp_data.append(group_matrix[j])
    for j,rule in zip(range(len(rules)),rules["Groups"]):
        if rule == "Leadership Dev":
            temp_data.append(group_matrix[j])
    
   
            
    if get_region(data["Office Location"][i]) == "LATAM":
        temp_data.extend(("N","N","Y","N"))
    elif get_region(data["Office Location"][i]) == "NAMER":
        temp_data.extend(("N","N","N","Y"))
    elif get_region(data["Office Location"][i]) == "APAC":
        temp_data.extend(("Y","N","N","N"))
    elif get_region(data["Office Location"][i]) == "EMEA":
        temp_data.extend(("N","Y","N","N"))
        
    csv.loc[len(csv)] = temp_data

# %%
csv
# Out:
#    UniqueID          FullName  FirstName  LastName                      Email  \
# 0    173657         Kim Blank        Kim     Blank         kim.blank@Acme.com
# 1    173658     Jeff Shilling       Jeff  Shilling     jeff.shilling@acme.com
# 2    173659      Nancy Barnes      Nancy    Barnes      nancy.barnes@acme.com
# 3    173660      Hank Edwards       Hank   Edwards      hank.edwards@acme.com
# 4    173661          Amy Cuth        Amy      Cuth          amy.cuth@acme.com
# 5    173662     Jaylan Walter     Jaylan    Walter     jaylan.walter@acme.com
# 6    172663      Nora Harrell       Nora   Harrell      nora.harrell@acme.com
# 7    173664     Carlos McCann     Carlos    McCann     carlos.mccann@acme.com
# 8    173665    Kailee Johnson     Kailee   Johnson    kailee.johnson@acme.com
# 9    173666  Mathias Villegas    Mathias  Villegas  mathias.villegas@acme.com
# 10   173667       Mylie Carey      Mylie     Carey       mylie.carey@acme.com
# 11   173668       Diego Duffy      Diego     Duffy       diego.duffy@acme.com
# 12   173669     Fatime Guerra     Fatima    Guerra     fatima.guerra@acme.com
# 13   173770     Joseph Osborn     Joseph    Osborn     joseph.osborn@acme.com
# 14   173771      Nora Sanchez       Nora   Sanchez      nora.sanchez@acme.com
# 15   173772       Derek Eaton     Derek      Eaton       derek.eaton@acme.com
# 16   173773    Karlie Hartman     Karlie   Hartman    karlie.hartman@acme.com
# 17   173774     Killian Bryan    Killian     Bryan     killian.bryan@acme.com
# 18   173775   Guillermo Josph  Guillermo    Joseph  guillermo.joseph@acme.com
# 19   173776        Hafiz Luna      Hafiz      Luna        hafiz.luna@acme.com
# 20   173777      Kate Huffman       Kate   Huffman      kate.huffman@acme.com
# 21   173778     Danielle West   Danielle      West     danielle.west@acme.com
# 22   173779         Alex Pace       Alex      Pace         alex.pace@acme.com
# 23   173780        Jamie Carr      Jamie      Carr        jamie.carr@acme.com
# 24   173781    Natalya Lucero    Natalya    Lucero    natalya.lucero@acme.com
#
#    ManagerUniqueID Delete                Department  Hire Date  \
# 0            11034      N               Procurement 2004-12-01
# 1            11587      N             Lead Sourcing 2010-01-08
# 2            10426      N              Supply Chain 2019-06-01
# 3            10033      N        Talent Acquisition 2003-03-05
# 4            14422      N                   Digital 2018-05-05
# 5            12256      N                     FP &A 2019-06-01
# 6            54956      N                     Field 2016-02-01
# 7            98122      N    Learning & Development 2018-10-02
# 8            98118      N              Supply Chain 2003-12-01
# 9            11053      N                   Digital 2003-12-01
# 10           11674      N               Procurement 2018-07-01
# 11           11987      N                     Field 2018-10-01
# 12           11524      N                        QA 2015-04-02
# 13           11999      N        Talent Acquisition 2004-12-01
# 14           11888      N  Partnerships & Alliances 2010-01-08
# 15           11678      N                Accounting 2019-06-01
# 16           11900      N                     Field 2003-03-05
# 17           11244      N                        QA 2018-05-05
# 18           11322      N    Learning & Development 2019-06-01
# 19           11544      N                   Digital 2016-02-01
# 20           16577      N                Accounting 2018-10-02
# 21           18395      N                     Field 2003-12-01
# 22           19835      N              Supply Chain 2003-12-01
# 23           12245      N        Talent Acquisition 2018-07-01
# 24           14556      N                   Digital 2018-10-01
#
#             Office Location  ... Finance Sales Production HR Marketing  \
# 0            Beijing, China  ...       Y     N          N  N         N
# 1                London, UK  ...       N     Y          N  N         N
# 2              Tokyo, Japan  ...       N     N          Y  N         N
# 3         Sao Paulo, Brazil  ...       N     N          N  Y         N
# 4       Mexico City, Mexico  ...       N     N          N  N         Y
# 5              New York, NY  ...       Y     N          N  N         N
# 6           Toronto, Canada  ...       N     Y          N  N         N
# 7          Bangalore, India  ...       N     N          N  Y         N
# 8           Los Angeles, CA  ...       N     N          Y  N         N
# 9               Chicago, IL  ...       N     N          N  N         Y
# 10  Buenos Aires, Argentina  ...       Y     N          N  N         N
# 11      Mexico City, Mexico  ...       N     Y          N  N         N
# 12        Sao Paulo, Brazil  ...       N     N          Y  N         N
# 13             New York, NY  ...       N     N          N  Y         N
# 14             New York, NY  ...       N     N          N  N         Y
# 15           Beijing, China  ...       Y     N          N  N         N
# 16           Beijing, China  ...       N     Y          N  N         N
# 17             Tokyo, Japan  ...       N     N          Y  N         N
# 18          Toronto, Canada  ...       N     N          N  Y         N
# 19               London, UK  ...       N     N          N  N         Y
# 20  Buenos Aires, Argentina  ...       Y     N          N  N         N
# 21          Los Angeles, CA  ...       N     Y          N  N         N
# 22          Los Angeles, CA  ...       N     N          Y  N         N
# 23          Toronto, Canada  ...       N     N          N  Y         N
# 24             New York, NY  ...       N     N          N  N         Y
#
#    Leadership Dev APAC EMEA LATAM NAMER
# 0               Y    Y    N     N     N
# 1               Y    N    Y     N     N
# 2               N    Y    N     N     N
# 3               N    N    N     Y     N
# 4               Y    N    N     N     Y
# 5               N    N    N     N     Y
# 6               Y    N    N     N     Y
# 7               Y    Y    N     N     N
# 8               N    N    N     N     Y
# 9               N    N    N     N     Y
# 10              N    N    N     Y     N
# 11              N    N    N     N     Y
# 12              Y    N    N     Y     N
# 13              Y    N    N     N     Y
# 14              Y    N    N     N     Y
# 15              N    Y    N     N     N
# 16              Y    Y    N     N     N
# 17              N    Y    N     N     N
# 18              Y    N    N     N     Y
# 19              Y    N    Y     N     N
# 20              Y    N    N     Y     N
# 21              N    N    N     N     Y
# 22              N    N    N     N     Y
# 23              Y    N    N     N     Y
# 24              Y    N    N     N     Y
#
# [25 rows x 23 columns]

# %%
csv_file = "User_File_Acme_"+date.today().strftime('%Y%m%d')+'.csv'

# %%
csv.to_csv(csv_file,index=False) ##CSV file to Server

# %%
csv.to_excel("User_file template_TIC_update_"+date.today().strftime('%Y%m%d')+ '.xlsx', index = False) ##Updated User Excel

# %%
rules.to_excel("BusinessRules Template_TIC_update_"+date.today().strftime('%Y%m%d')+ '.xlsx', index = False) ##Updated Rules Excel

# %% [markdown]
# ## 10. Sending Data to AWS sSTP Linux Server

# %%
import subprocess

# %%
pem = r"c:\Users\guibo\OneDrive\Área de Trabalho\Degreed\LightsailDefaultKey-us-east-1.pem"
csv2server = 'c:\\Users\\guibo\\OneDrive\\Área de Trabalho\\Degreed\\'  + csv_file
host = 'ec2-user@3.235.6.48:~'

# %%
subprocess.run(["scp","-i", pem, csv2server, host])
# Out:
# CompletedProcess(args=['scp', '-i', 'c:\\Users\\guibo\\OneDrive\\Área de Trabalho\\Degreed\\LightsailDefaultKey-us-east-1.pem', 'c:\\Users\\guibo\\OneDrive\\Área de Trabalho\\Degreed\\User_File_Acme_20200520.csv', 'ec2-user@3.235.6.48:~'], returncode=0)
